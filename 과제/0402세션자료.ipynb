# %%
import warnings
warnings.filterwarnings("ignore")

# %matplotlib notebook
import matplotlib.pyplot as plt

import seaborn as sns

tips = sns.load_dataset("tips")
anscombe = sns.load_dataset("anscombe")

# %% [markdown]
# # 다양한 종류의 이변량 그래프 그리기
# ## 8. 관계 그래프 그리기

# %%
fig = sns.pairplot(tips)

# %%
pair_grid = sns.PairGrid(tips)
pair_grid = pair_grid.map_upper(sns.regplot)
pair_grid = pair_grid.map_lower(sns.kdeplot)
pari_grid = pair_grid.map_diag(sns.distplot, rug = True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="843.5555555555555">

# %% [markdown]
# # 다변량 그래프 그리기
# ## 1. seaborn 라이브러리로 바이올린 그래프 그리기 - 색상 추가

# %%
ax = plt.subplots()
ax = sns.violinplot(x = 'time', y = 'total_bill', hue = 'sex', data = tips, split = True)
# Out:
# <img src="data:image/png;base64,..." width="533.999974536897">

# %%
ax = plt.subplots()
ax = sns.violinplot(x = 'time', y = 'total_bill', hue = 'sex', data = tips, split = False)
# Out:
# <img src="data:image/png;base64,..." width="639.5999695014968">

# %% [markdown]
# ## 2. 산점도, 관계 그래프 그리기 - 색상 추가

# %%
scatter = sns.lmplot(x = 'total_bill', y = 'tip', data = tips, hue = 'sex', fit_reg = False)
# Out:
# <img src="data:image/png;base64,..." width="500.39997613906974">

# %%
fig = sns.pairplot(tips, hue = 'sex')
# Out:
# <img src="data:image/png;base64,..." width="707.9999662399308">

# %% [markdown]
# ## 3. 산점도 그래프의 크기와 모양 조절하기

# %%
scatter = sns.lmplot(x = 'total_bill', y = 'tip', data = tips, fit_reg = False, scatter_kws = {'s': tips['size']*10}, hue = 'sex' )
# Out:
# <div id='8d9e4d8b-a483-420a-b7a8-b226c67ee97a'></div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-dd452fa1d7c2> in <module>
# ----> 1 scatter = sns.lmplot(x = 'total_bill', y = 'tip', data = tips, fit_reg = False, scatter_kws = {'s': tips['size']*10}, hue = 'sex' )
#
# C:\Python\Anaconda3\envs\tf2_py37\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
print('total_bill 사이즈:',tips['total_bill'].shape)
print('tip 사이즈', tips['tip'].shape)
print('size 사이즈', tips['size'].shape)
# Out:
# total_bill 사이즈: (244,)
# tip 사이즈 (244,)
# size 사이즈 (244,)

# %%
type(tips['size'])
# Out:
# pandas.core.series.Series

# %%
scatter = sns.lmplot(x = 'total_bill', y = 'tip', data = tips, fit_reg = False, scatter_kws = {'s': 100}, hue = 'sex' )
# Out:
# <img src="data:image/png;base64,..." width="500.39997613906974">

# %% [markdown]
# ## 4. 산점도 그래프의 점 기호 변경

# %%
scatter = sns.lmplot(x = 'total_bill', y = 'tip', data = tips, fit_reg = False, markers = ['o', 'x'], scatter_kws = {'s': tips['size']*10}, hue = 'sex' )

# %%
scatter = sns.lmplot(x = 'total_bill', y = 'tip', data = tips, 
                     fit_reg = False, markers = ['o', 'x'], scatter_kws = {'s':30}, hue = 'sex' )
# Out:
# <img src="data:image/png;base64,..." width="500.39997613906974">

# %% [markdown]
# ## 5. lmplot 메서드로 4개의 데이터 그룹에 대한 그래프 한 번에 그리기

# %%
anscombe_plot = sns.lmplot(x = 'x', y = 'y', data = anscombe, fit_reg = False)
# Out:
# <img src="data:image/png;base64,..." width="416.3999801445017">

# %%
anscombe['dataset'].unique()
# Out:
# array(['I', 'II', 'III', 'IV'], dtype=object)

# %% [markdown]
# ## 6. 그룹별로 그래프 나누어 그리기

# %%
anscombe_plot = sns.lmplot(x = 'x', y = 'y', data = anscombe, fit_reg = False, col = 'dataset', col_wrap = 4)
# Out:
# <img src="data:image/png;base64,..." width="1665.5999205780067">

# %% [markdown]
# # FaceGrid 클래스로도 그룹별 그래프를 그릴 수 있습니다.
# ## 1. 객체 생성 후 그래프 그리기

# %%
facet = sns.FacetGrid(tips, col = 'time')
facet.map(sns.distplot, 'total_bill', rug = True)
# Out:
# <img src="data:image/png;base64,..." width="599.9999713897719">

# %%
tips['time'].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Dinner', 'Lunch']

# %% [markdown]
# ## 2. 다변량 그래프 그리기

# %%
facet = sns.FacetGrid(tips, col = 'day', hue = 'sex')
facet = facet.map(plt.scatter, 'total_bill', 'tip')
facet = facet.add_legend()
# Out:
# <img src="data:image/png;base64,..." width="1083.599948329928">

# %%
tips['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Sun', 'Sat', 'Thur', 'Fri']

# %% [markdown]
# ## 3. 더 많은 변수로 그리기

# %%
facet = sns.FacetGrid(tips, col = 'time', row = 'smoker', hue = 'sex')
facet.map(plt.scatter, 'total_bill', 'tip')
# Out:
# <img src="data:image/png;base64,..." width="599.9999713897719">

# %%
tips['time'].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Dinner', 'Lunch']

# %%
tips['smoker'].unique()
# Out:
# ['No', 'Yes']
# Categories (2, object): ['No', 'Yes']
