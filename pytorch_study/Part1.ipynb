# %% [markdown]
# # 04 반드시 알아야 하는 파이토치 스킬
# ## 4.1 텐서
# ### 4.1.1 Scala

# %%
import torch

# %%
scalar1 = torch.tensor([1.])
print(scalar1)
# Out:
# tensor([1.])

# %%
scalar2 = torch.tensor([3.])
print(scalar2)
# Out:
# tensor([3.])

# %%
add_scalar = scalar1 + scalar2
print(add_scalar)
# Out:
# tensor([4.])

# %%
sub_scalar = scalar1 - scalar2
print(sub_scalar)
# Out:
# tensor([-2.])

# %%
mul_scalar = scalar1 * scalar2
print(mul_scalar)
# Out:
# tensor([3.])

# %%
div_scalar = scalar1 / scalar2
print(div_scalar)
# Out:
# tensor([0.3333])

# %%
torch.add(scalar1, scalar2)
# Out:
# tensor([4.])

# %%
torch.sub(scalar1, scalar2)
# Out:
# tensor([-2.])

# %%
torch.mul(scalar1, scalar2)
# Out:
# tensor([3.])

# %%
torch.div(scalar1, scalar2)
# Out:
# tensor([0.3333])

# %% [markdown]
# ### 4.1.2 Vector

# %%
vector1 = torch.tensor([1., 2., 3.])
print(vector1)
# Out:
# tensor([1., 2., 3.])

# %%
vector2 = torch.tensor([4., 5., 6.])
print(vector2)
# Out:
# tensor([4., 5., 6.])

# %%
add_vector = vector1 + vector2
print(add_vector)
# Out:
# tensor([5., 7., 9.])

# %%
sub_vector = vector1 - vector2
print(sub_vector)
# Out:
# tensor([-3., -3., -3.])

# %%
mul_vector = vector1 * vector2
print(mul_vector)
# Out:
# tensor([ 4., 10., 18.])

# %%
div_vector = vector1 / vector2
print(div_vector)
# Out:
# tensor([0.2500, 0.4000, 0.5000])

# %%
torch.add(vector1, vector2)
# Out:
# tensor([5., 7., 9.])

# %%
torch.sub(vector1, vector2)
# Out:
# tensor([-3., -3., -3.])

# %%
torch.mul(vector1, vector2)
# Out:
# tensor([ 4., 10., 18.])

# %%
torch.div(vector1, vector2)
# Out:
# tensor([0.2500, 0.4000, 0.5000])

# %%
torch.dot(vector1, vector2)
# Out:
# tensor(32.)

# %% [markdown]
# ### 4.1.3 행렬

# %%
matrix1 = torch.tensor([[1., 2.], [3., 4.]])
print(matrix1)
# Out:
# tensor([[1., 2.],
#         [3., 4.]])

# %%
matrix2 = torch.tensor([[5., 6.], [7., 8.]])
print(matrix2)
# Out:
# tensor([[5., 6.],
#         [7., 8.]])

# %%
sum_matrix = matrix1 + matrix2
print(sum_matrix)
# Out:
# tensor([[ 6.,  8.],
#         [10., 12.]])

# %%
sub_matrix = matrix1 - matrix2
print(sub_matrix)
# Out:
# tensor([[-4., -4.],
#         [-4., -4.]])

# %%
mul_matrix = matrix1 * matrix2
print(mul_matrix)
# Out:
# tensor([[ 5., 12.],
#         [21., 32.]])

# %%
div_matrix = matrix1 / matrix2
print(div_matrix)
# Out:
# tensor([[0.2000, 0.3333],
#         [0.4286, 0.5000]])

# %%
torch.add(matrix1, matrix2)
# Out:
# tensor([[ 6.,  8.],
#         [10., 12.]])

# %%
torch.sub(matrix1, matrix2)
# Out:
# tensor([[-4., -4.],
#         [-4., -4.]])

# %%
torch.mul(matrix1, matrix2)
# Out:
# tensor([[ 5., 12.],
#         [21., 32.]])

# %%
torch.div(matrix1, matrix2)
# Out:
# tensor([[0.2000, 0.3333],
#         [0.4286, 0.5000]])

# %%
# 행렬 곱
torch.matmul(matrix1, matrix2)
# Out:
# tensor([[19., 22.],
#         [43., 50.]])

# %% [markdown]
# ### 4.1.4  텐서

# %%
tensor1 = torch.tensor([[[1., 2.], [3., 4.]], [[5., 6.], [7., 8.]]])
print(tensor1)
# Out:
# tensor([[[1., 2.],
#          [3., 4.]],
#
#         [[5., 6.],
#          [7., 8.]]])

# %%
tensor2 = torch.tensor([[[9., 10.], [11., 12.]], [[13., 14.], [15., 16.]]])
print(tensor2)
# Out:
# tensor([[[ 9., 10.],
#          [11., 12.]],
#
#         [[13., 14.],
#          [15., 16.]]])

# %%
sum_tensor = tensor1 + tensor2
print(sum_tensor)
# Out:
# tensor([[[10., 12.],
#          [14., 16.]],
#
#         [[18., 20.],
#          [22., 24.]]])

# %%
sub_tensor = tensor1 - tensor2
print(sub_tensor)
# Out:
# tensor([[[-8., -8.],
#          [-8., -8.]],
#
#         [[-8., -8.],
#          [-8., -8.]]])

# %%
mul_tensor = tensor1 * tensor2
print(mul_tensor)
# Out:
# tensor([[[  9.,  20.],
#          [ 33.,  48.]],
#
#         [[ 65.,  84.],
#          [105., 128.]]])

# %%
div_tensor = tensor1 / tensor2
print(div_tensor)
# Out:
# tensor([[[0.1111, 0.2000],
#          [0.2727, 0.3333]],
#
#         [[0.3846, 0.4286],
#          [0.4667, 0.5000]]])

# %%
torch.add(tensor1, tensor2)
# Out:
# tensor([[[10., 12.],
#          [14., 16.]],
#
#         [[18., 20.],
#          [22., 24.]]])

# %%
torch.sub(tensor1, tensor2)
# Out:
# tensor([[[-8., -8.],
#          [-8., -8.]],
#
#         [[-8., -8.],
#          [-8., -8.]]])

# %%
torch.mul(tensor1, tensor2)
# Out:
# tensor([[[  9.,  20.],
#          [ 33.,  48.]],
#
#         [[ 65.,  84.],
#          [105., 128.]]])

# %%
torch.div(tensor1, tensor2)
# Out:
# tensor([[[0.1111, 0.2000],
#          [0.2727, 0.3333]],
#
#         [[0.3846, 0.4286],
#          [0.4667, 0.5000]]])

# %%
torch.matmul(tensor1, tensor2)
# Out:
# tensor([[[ 31.,  34.],
#          [ 71.,  78.]],
#
#         [[155., 166.],
#          [211., 226.]]])

# %% [markdown]
# ## 4.2 Autograd

# %%
import torch

if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')

# %%
BATCH_SIZE = 64   # 파라미터 업데이트할 때 계산되는 데이터 개수
INPUT_SIZE = 1000 # input의 크기이자 입력층의 노드 수
HIDDEN_SIZE = 100 # 은닉층의 노드 수    => (64, 1000) * (1000, 100)
OUTPUT_SIZE = 10  # 최종으로 출력되는 값의 벡터 크기(레이블 크기와 동일)

# %%
x = torch.randn(BATCH_SIZE,
               INPUT_SIZE,
               device = DEVICE,
               dtype = torch.float,
               requires_grad = False)

y = torch.randn(BATCH_SIZE,
               OUTPUT_SIZE,
               device = DEVICE,
               dtype = torch.float,
               requires_grad = False)

w1 = torch.randn(INPUT_SIZE, 
                 HIDDEN_SIZE, 
                 device = DEVICE, 
                 dtype = torch.float,
                 requires_grad = True)  

w2 = torch.randn(HIDDEN_SIZE,
                 OUTPUT_SIZE, 
                 device = DEVICE,
                 dtype = torch.float,
                 requires_grad = True)

# %%
learning_rate = 1e-6
for t in range(1, 501):
    y_pred = x.mm(w1).clamp(min = 0).mm(w2)
    
    loss = (y_pred - y).pow(2).sum()
    if t % 100 == 0:
        print("Iteration: ", t, '\t', 'Loss: ', loss.item())
    loss.backward()
    
    with torch.no_grad():
        w1 -= learning_rate * w1.grad
        w2 -= learning_rate * w2.grad
        
        w1.grad.zero_()
        w2.grad.zero_()
# Out:
# Iteration:  100 	 Loss:  528.1594848632812
# Iteration:  200 	 Loss:  2.9453721046447754
# Iteration:  300 	 Loss:  0.025970520451664925
# Iteration:  400 	 Loss:  0.000518301734700799
# Iteration:  500 	 Loss:  6.999580364208668e-05
